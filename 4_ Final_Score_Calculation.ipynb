# %%
# Import all relevant libraries to the note book
import osmnx as ox
import pandas as pd
import networkx as nx
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import shapely
import fiona
import jenkspy

# %% [markdown]
# Set Up GeoDataFrame

# %%
# Load the walking network with the common code
area_shape = fiona.open("root/Inputs/GemeenteAmsterdam.geojson")
area_shape = shapely.geometry.shape(area_shape[0]['geometry'])

cf = """
     ["area"!~"yes"]
     ["highway"]
     ["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]
     ["foot"!~"no"]
     ["service"!~"private"]
     ["access"!~"private"]
     """

G = ox.graph_from_polygon(polygon=area_shape, custom_filter=cf, simplify=False, retain_all=True, network_type="walk", truncate_by_edge=True)

# Convert to GeoDataFrame
geoDataFrame = ox.graph_to_gdfs(G, nodes=False, edges=True,  node_geometry=False, fill_edge_geometry=True)

# %%
#Ensure that the u column is not a index so reset accordingly
geoDataFrame = geoDataFrame.reset_index()
print(geoDataFrame)
# Out:
#                   u            v  key       osmid  oneway       name  \
# 0           6316199   1360288038    0     4745774   False  Raamsteeg
# 1           6316199    451946447    0     7372610   False        NaN
# 2           6316199     46388769    0     7372614   False     Singel
# 3           6316199   5825714203    0   562720340   False     Singel
# 4          16568167   3175727845    0   311836384   False        NaN
# ...             ...          ...  ...         ...     ...        ...
# 535731  12433165560  12433165518    0   321291099   False    Heining
# 535732  12433165560   5030753737    0   321291099   False    Heining
# 535733  12433165560  12433165559    0  1343730529   False        NaN
# 535734  12433165561   7890327903    0  1343730528   False        NaN
# 535735  12433165561  12433165559    0  1343730529   False        NaN
#
#              highway width  reversed   length  ... bridge tunnel lanes access  \
# 0           cycleway  1.80      True    5.164  ...    NaN    NaN   NaN    NaN
# 1        residential   NaN     False    8.514  ...    NaN    NaN   NaN    NaN
# 2        residential   NaN     False  198.768  ...    NaN    NaN   NaN    NaN
# 3        residential   NaN      True   11.452  ...    NaN    NaN   NaN    NaN
# 4            footway   NaN     False    3.523  ...    NaN    NaN   NaN    NaN
# ...              ...   ...       ...      ...  ...    ...    ...   ...    ...
# 535731  unclassified   NaN     False    7.191  ...    NaN    NaN   NaN    NaN
# 535732  unclassified   NaN      True    8.729  ...    NaN    NaN   NaN    NaN
# 535733       service   NaN     False   24.616  ...    NaN    NaN   NaN    NaN
# 535734       service   NaN     False   20.983  ...    NaN    NaN   NaN    NaN
# 535735       service   NaN      True   79.300  ...    NaN    NaN   NaN    NaN
#
#         ref        service junction est_width area  \
# 0       NaN            NaN      NaN       NaN  NaN
# 1       NaN            NaN      NaN       NaN  NaN
# 2       NaN            NaN      NaN       NaN  NaN
# 3       NaN            NaN      NaN       NaN  NaN
# 4       NaN            NaN      NaN       NaN  NaN
# ...     ...            ...      ...       ...  ...
# 535731  NaN            NaN      NaN       NaN  NaN
# 535732  NaN            NaN      NaN       NaN  NaN
# 535733  NaN  parking_aisle      NaN       NaN  NaN
# 535734  NaN  parking_aisle      NaN       NaN  NaN
# 535735  NaN  parking_aisle      NaN       NaN  NaN
#
#                                                geometry
# 0       LINESTRING (4.88840 52.37017, 4.88847 52.37017)
# 1       LINESTRING (4.88840 52.37017, 4.88827 52.37018)
# 2       LINESTRING (4.88840 52.37017, 4.88873 52.37195)
# 3       LINESTRING (4.88840 52.37017, 4.88838 52.37007)
# 4       LINESTRING (4.89910 52.37785, 4.89913 52.37787)
# ...                                                 ...
# 535731  LINESTRING (4.77145 52.39935, 4.77144 52.39941)
# 535732  LINESTRING (4.77145 52.39935, 4.77145 52.39927)
# 535733  LINESTRING (4.77145 52.39935, 4.77181 52.39935)
# 535734  LINESTRING (4.77298 52.39936, 4.77297 52.39954)
# 535735  LINESTRING (4.77298 52.39936, 4.77181 52.39935)
#
# [535736 rows x 21 columns]

# %%
# To prevent double counting of two way streets the edges are grouped by the same u and v columns and then split again after selecting for the first street
geoDataFrame['edge'] = geoDataFrame.apply(lambda row: tuple(sorted([row['u'], row['v']])), axis=1)
gdf_combined = geoDataFrame.groupby('edge').first().reset_index()
gdf_combined[['u', 'v']] = pd.DataFrame(gdf_combined['edge'].tolist(), index=gdf_combined.index)

print(gdf_combined)
# Out:
#                               edge            u            v  key       osmid  \
# 0              (6316199, 46388769)      6316199     46388769    0     7372614
# 1             (6316199, 451946447)      6316199    451946447    0     7372610
# 2            (6316199, 1360288038)      6316199   1360288038    0     4745774
# 3            (6316199, 5825714203)      6316199   5825714203    0   562720340
# 4           (16568167, 3175727845)     16568167   3175727845    0   311836384
# ...                            ...          ...          ...  ...         ...
# 267857  (12433165456, 12433165457)  12433165456  12433165457    0    37618224
# 267858  (12433165458, 12433165459)  12433165458  12433165459    0    37618224
# 267859  (12433165518, 12433165560)  12433165518  12433165560    0   321291099
# 267860  (12433165559, 12433165560)  12433165559  12433165560    0  1343730529
# 267861  (12433165559, 12433165561)  12433165559  12433165561    0  1343730529
#
#         oneway       name       highway width  reversed  ...  bridge tunnel  \
# 0        False     Singel   residential  None     False  ...    None   None
# 1        False       None   residential  None     False  ...    None   None
# 2        False  Raamsteeg      cycleway  1.80      True  ...    None   None
# 3        False     Singel   residential  None      True  ...    None   None
# 4        False       None       footway  None     False  ...    None   None
# ...        ...        ...           ...   ...       ...  ...     ...    ...
# 267857   False       None      cycleway  None     False  ...    None   None
# 267858   False       None      cycleway  None     False  ...    None   None
# 267859   False    Heining  unclassified  None      True  ...    None   None
# 267860   False       None       service  None      True  ...    None   None
# 267861   False       None       service  None     False  ...    None   None
#
#        lanes access   ref        service junction est_width  area  \
# 0       None   None  None           None     None      None  None
# 1       None   None  None           None     None      None  None
# 2       None   None  None           None     None      None  None
# 3       None   None  None           None     None      None  None
# 4       None   None  None           None     None      None  None
# ...      ...    ...   ...            ...      ...       ...   ...
# 267857  None   None  None           None     None      None  None
# 267858  None   None  None           None     None      None  None
# 267859  None   None  None           None     None      None  None
# 267860  None   None  None  parking_aisle     None      None  None
# 267861  None   None  None  parking_aisle     None      None  None
#
#                                                geometry
# 0       LINESTRING (4.88840 52.37017, 4.88873 52.37195)
# 1       LINESTRING (4.88840 52.37017, 4.88827 52.37018)
# 2       LINESTRING (4.88840 52.37017, 4.88847 52.37017)
# 3       LINESTRING (4.88840 52.37017, 4.88838 52.37007)
# 4       LINESTRING (4.89910 52.37785, 4.89913 52.37787)
# ...                                                 ...
# 267857  LINESTRING (4.77171 52.39899, 4.77171 52.39904)
# 267858  LINESTRING (4.77169 52.39913, 4.77168 52.39913)
# 267859  LINESTRING (4.77144 52.39941, 4.77145 52.39935)
# 267860  LINESTRING (4.77181 52.39935, 4.77145 52.39935)
# 267861  LINESTRING (4.77181 52.39935, 4.77298 52.39936)
#
# [267862 rows x 22 columns]

# %%
#Store network in case it is needed
with open('./root/Outputs/Network_Amsterdam.geojson' , 'w') as file:
    file.write(gdf_combined.to_json())

# %%
#Pull all files from previous script - should be geojson or geo-package
file_mobility = "./root/Outputs/2_modelled_pedestrian_intensity.gpkg" # fill in full path
file_shade_PET = "./root/Outputs/3_Shade+PET.gpkg" # fill in full path

# %%
#Read the files into GeoDataFrames and save the columns that are needed only
gdf_mobility = gpd.read_file(file_mobility)
gdf_mobility = gdf_mobility[['u', 'v', 'pop', 'buurtcode', 'young_pop_pct', 'old_pop_pct', 'pop_unknown_pct']]
gdf_mobility['u'] = gdf_mobility['u'].astype('int64')
gdf_mobility['v'] = gdf_mobility['v'].astype('int64')
gdf_shade = gpd.read_file(file_shade_PET)
gdf_shade = gdf_shade[['u', 'v', "0900",  "0930", "1000", "1030", "1100", "1130", "1200", "1230", "1300", "1330", "1400", "1430", "1500", "1530", "1600", "1630", "1700", "1730", "1800", "1830", "1900", "1930", "2000", "sum_adjust", 'PET', "avg_exposure_percent", 'avg_shade_percent']]

# %%
#Again to prevent double counting the first street is selected
gdf_shade['edge'] = gdf_shade.apply(lambda row: tuple(sorted([row['u'], row['v']])), axis=1)
gdf_shade_combined = gdf_shade.groupby('edge').first().reset_index()
gdf_shade_combined [['u', 'v']] = pd.DataFrame(gdf_combined['edge'].tolist(), index=gdf_combined.index)

# %%
print(gdf_shade_combined)
print(gdf_mobility)
print(gdf_combined)
# Out:
#                   u           v      0900      0930      1000      1030  \
# 0           6316199  1360288038  0.073318  0.010515  0.062450  0.107095
# 1           6316199   451946447  0.144737  0.074230  0.189317  0.160753
# 2           6316199    46388769  0.017194  0.007147  0.016331  0.023917
# 3           6316199  5825714203  0.053952  0.005449  0.046026  0.080215
# 4          16568167  3175727845  0.960552  0.960552  0.977149  0.985047
# ...             ...         ...       ...       ...       ...       ...
# 535287  12397581807  1426936884  0.639661  0.567187  0.676846  0.692416
# 535288  12398264801   350431665  0.132534  0.039515  0.131939  0.118753
# 535289  12398264801  4653799513  0.198753  0.087807  0.208488  0.274880
# 535290  12398264802   311590674  0.099197  0.009920  0.100000  0.100000
# 535291  12398264802   350431665  0.100000  0.010000  0.100000  0.100000
#
#             1100      1130      1200      1230  ...      1730      1800  \
# 0       0.096896  0.074288  0.097006  0.249836  ...  0.866796  0.874066
# 1       0.141620  0.209959  0.310455  0.436045  ...  0.895881  0.907743
# 2       0.021691  0.018950  0.045616  0.150249  ...  0.445192  0.433017
# 3       0.070846  0.053614  0.078791  0.201755  ...  0.679265  0.692903
# 4       0.990127  0.992101  0.998025  0.997038  ...  0.999013  0.999013
# ...          ...       ...       ...       ...  ...       ...       ...
# 535287  0.718481  0.736085  0.744283  0.756443  ...  0.698381  0.624041
# 535288  0.123239  0.134083  0.126337  0.128078  ...  0.100000  0.100000
# 535289  0.301122  0.312776  0.300283  0.290175  ...  0.164442  0.119880
# 535290  0.100000  0.100000  0.100000  0.100000  ...  0.100000  0.100000
# 535291  0.100000  0.100000  0.100000  0.100000  ...  0.100000  0.100000
#
#             1830      1900      1930      2000  sum_adjust        PET  \
# 0       0.876992  0.875900  0.860478  0.640534   11.136600  40.909272
# 1       0.915323  0.920616  0.866935  0.541613   12.824279  41.524704
# 2       0.425739  0.393474  0.296595  0.139121    7.210930  38.557958
# 3       0.700697  0.708817  0.708727  0.550037    9.541534  41.227089
# 4       0.998025  0.997038  0.993984  0.988060   20.693201  40.568399
# ...          ...       ...       ...       ...         ...        ...
# 535287  0.479051  0.337723  0.225169  0.115889   14.108726  39.620682
# 535288  0.100000  0.100000  0.100000  0.100000    2.361645  38.866513
# 535289  0.100904  0.100751  0.099621  0.097844    4.722361  40.057587
# 535290  0.100000  0.100000  0.100000  0.100000    2.018473  38.745288
# 535291  0.100000  0.100000  0.100000  0.100000    2.019100  38.880275
#
#         avg_exposure_percent  avg_shade_percent
# 0                   0.524554           0.475446
# 1                   0.632259           0.367741
# 2                   0.414644           0.585356
# 3                   0.466592           0.533408
# 4                   0.997646           0.002354
# ...                      ...                ...
# 535287              0.785273           0.214727
# 535288              0.120142           0.879858
# 535289              0.278891           0.721109
# 535290              0.100000           0.900000
# 535291              0.100000           0.900000
#
# [535292 rows x 29 columns]
#                  u            v  pop  \
# 0          6316199     46388769   26
# 1          6316199    451946447  525
# 2          6316199   1360288038  499
# 3         25596455     46356773  215
# 4         25596455   8383889398  190
# ...            ...          ...  ...
# 88808  12406685654  12406685655   73
# 88809  12406685655  12406685656   45
# 88810  12406685660  12406685661  128
# 88811  12414109945  12414109968   10
# 88812  12416122532  12416122534   15
#
#                                                buurtcode  young_pop_pct  \
# 0                                     {"BU0363AC03": 26}      15.384615
# 1      {"BU0363AC03": 261, "BU0363AC04": 76, "BU0363A...       5.714286
# 2      {"BU0363AC03": 235, "BU0363AC04": 76, "BU0363A...       5.210421
# 3      {"BU0363AK08": 25, "BU0363AJ02": 8, "BU0363AJ0...       9.767442
# 4                   {"BU0363AJ02": 8, "BU0363AJ04": 182}      10.000000
# ...                                                  ...            ...
# 88808               {"BU03940551": 47, "BU03940556": 26}       2.739726
# 88809                                 {"BU03940551": 45}       0.000000
# 88810              {"BU03940551": 13, "BU03940554": 115}       4.687500
# 88811                                 {"BU0363NQ03": 10}       0.000000
# 88812                                 {"BU0363NN02": 15}      13.333333
#
#        old_pop_pct  pop_unknown_pct
# 0         0.000000              0.0
# 1        12.571429              0.0
# 2        13.226453              0.0
# 3        11.162791              0.0
# 4        10.000000              0.0
# ...            ...              ...
# 88808     5.479452              0.0
# 88809     0.000000              0.0
# 88810    12.500000              0.0
# 88811     0.000000              0.0
# 88812    13.333333              0.0
#
# [88813 rows x 7 columns]
#                               edge            u            v  key       osmid  \
# 0              (6316199, 46388769)      6316199     46388769    0     7372614
# 1             (6316199, 451946447)      6316199    451946447    0     7372610
# 2            (6316199, 1360288038)      6316199   1360288038    0     4745774
# 3            (6316199, 5825714203)      6316199   5825714203    0   562720340
# 4           (16568167, 3175727845)     16568167   3175727845    0   311836384
# ...                            ...          ...          ...  ...         ...
# 374576  (12424968531, 12424968532)  12424968531  12424968532    0  1342935893
# 374577  (12424968539, 12424968541)  12424968539  12424968541    0   704396771
# 374578  (12424968539, 12424968546)  12424968539  12424968546    0  1342935899
# 374579  (12424968540, 12424968541)  12424968540  12424968541    0   704396771
# 374580  (12424968541, 12424968544)  12424968541  12424968544    0   939058000
#
#         oneway        name       highway width  reversed  ...  bridge tunnel  \
# 0        False      Singel   residential  None     False  ...    None   None
# 1        False        None   residential  None     False  ...    None   None
# 2        False   Raamsteeg      cycleway  1.80      True  ...    None   None
# 3        False      Singel   residential  None      True  ...    None   None
# 4        False        None       footway  None     False  ...    None   None
# ...        ...         ...           ...   ...       ...  ...     ...    ...
# 374576   False        None       service  None      True  ...    None   None
# 374577   False        None       footway  None      True  ...    None   None
# 374578   False        None       footway  None     False  ...    None   None
# 374579   False        None       footway  None     False  ...    None   None
# 374580   False  Pampuslaan  unclassified   5.5     False  ...    None   None
#
#        lanes access   ref service junction est_width  area  \
# 0       None   None  None    None     None      None  None
# 1       None   None  None    None     None      None  None
# 2       None   None  None    None     None      None  None
# 3       None   None  None    None     None      None  None
# 4       None   None  None    None     None      None  None
# ...      ...    ...   ...     ...      ...       ...   ...
# 374576  None   None  None    None     None      None  None
# 374577  None   None  None    None     None      None  None
# 374578  None   None  None    None     None      None  None
# 374579  None   None  None    None     None      None  None
# 374580     2   None  None    None     None      None  None
#
#                                                geometry
# 0       LINESTRING (4.88840 52.37017, 4.88873 52.37195)
# 1       LINESTRING (4.88840 52.37017, 4.88827 52.37018)
# 2       LINESTRING (4.88840 52.37017, 4.88847 52.37017)
# 3       LINESTRING (4.88840 52.37017, 4.88838 52.37007)
# 4       LINESTRING (4.89910 52.37785, 4.89913 52.37787)
# ...                                                 ...
# 374576  LINESTRING (5.01916 52.35634, 5.01892 52.35631)
# 374577  LINESTRING (5.01222 52.35355, 5.01217 52.35360)
# 374578  LINESTRING (5.01222 52.35355, 5.01218 52.35354)
# 374579  LINESTRING (5.01214 52.35365, 5.01217 52.35360)
# 374580  LINESTRING (5.01217 52.35360, 5.01209 52.35357)
#
# [374581 rows x 22 columns]

# %%
#Combine all GeoDataFrames into one file
gdf_heat_combined = gdf_combined.merge(gdf_shade_combined, how = 'left', on =['u', 'v']) 
gdf_heat_combined = gdf_heat_combined.merge(gdf_mobility, how = 'left', on =['u', 'v']) 
print(gdf_heat_combined.head(30))
# Out:
#                      edge_x         u            v  key      osmid  oneway  \
# 0       (6316199, 46388769)   6316199     46388769    0    7372614   False
# 1      (6316199, 451946447)   6316199    451946447    0    7372610   False
# 2     (6316199, 1360288038)   6316199   1360288038    0    4745774   False
# 3     (6316199, 5825714203)   6316199   5825714203    0  562720340   False
# 4    (16568167, 3175727845)  16568167   3175727845    0  311836384   False
# 5   (16568167, 10633464529)  16568167  10633464529    0  311836398   False
# 6      (25596455, 46356773)  25596455     46356773    0   37481780   False
# 7    (25596455, 8383889398)  25596455   8383889398    0   37481780   False
# 8    (25596455, 8383889399)  25596455   8383889399    0   37481778   False
# 9    (25596455, 8383889401)  25596455   8383889401    0   37481778   False
# 10   (25596477, 2739513281)  25596477   2739513281    0   23289375   False
# 11   (25596477, 2739513283)  25596477   2739513283    0  113952975   False
# 12   (25596477, 9033130238)  25596477   9033130238    0   23289374   False
# 13     (25645986, 25645987)  25645986     25645987    0   37481778   False
# 14     (25645986, 46352556)  25645986     46352556    0   37481778   False
# 15   (25645987, 4854477788)  25645987   4854477788    0   37481778   False
# 16   (25645988, 4854477788)  25645988   4854477788    0   37481778   False
# 17   (25645988, 8383889402)  25645988   8383889402    0   37481778   False
# 18     (25645989, 46359454)  25645989     46359454    0   37481777   False
# 19    (25645989, 438278570)  25645989    438278570    0   37481778   False
# 20   (25645989, 8383889374)  25645989   8383889374    0   37481778   False
# 21     (25645990, 46361924)  25645990     46361924    0    7046058   False
# 22    (25645990, 452982483)  25645990    452982483    0   33514339   False
# 23  (25645990, 10012107912)  25645990  10012107912    0  115708738   False
# 24   (25658577, 3307094070)  25658577   3307094070    0  504684738   False
# 25   (25658577, 4589025084)  25658577   4589025084    0  115743517   False
# 26   (25658577, 9831335847)  25658577   9831335847    0    4270806   False
# 27     (25658578, 25658580)  25658578     25658580    0    4270806   False
# 28   (25658578, 1367854685)  25658578   1367854685    0    4270806   False
# 29   (25658578, 9831335842)  25658578   9831335842    0  323937630   False
#
#                         name      highway width  reversed  ...      2000  \
# 0                     Singel  residential  None     False  ...  0.139121
# 1                       None  residential  None     False  ...  0.541613
# 2                  Raamsteeg     cycleway  1.80      True  ...  0.640534
# 3                     Singel  residential  None      True  ...  0.550037
# 4                       None      footway  None     False  ...  0.988060
# 5                       None      footway  None     False  ...  0.996336
# 6   Wilhelmina Blombergplein   pedestrian  None      True  ...  0.187785
# 7   Wilhelmina Blombergplein   pedestrian  None     False  ...  0.224533
# 8              Alexanderkade      footway  None      True  ...  0.259624
# 9              Alexanderkade      footway  None     False  ...  0.199400
# 10        Nieuwe Herengracht  residential  None     False  ...  0.082919
# 11  Jonas Daniël Meijerplein   pedestrian  None      True  ...  0.167136
# 12  Jonas Daniël Meijerplein   pedestrian  None      True  ...  0.096876
# 13             Alexanderkade      footway  None      True  ...  0.000000
# 14             Alexanderkade      footway  None     False  ...  0.000000
# 15             Alexanderkade      footway  None      True  ...  0.000000
# 16             Alexanderkade      footway  None     False  ...  0.049654
# 17             Alexanderkade      footway  None      True  ...  0.052606
# 18                      None      footway  None      True  ...  0.056407
# 19             Alexanderkade      footway  None     False  ...  0.006640
# 20             Alexanderkade      footway  None      True  ...  0.024032
# 21                      None     cycleway  1.80     False  ...  0.000000
# 22                      None     cycleway  1.65     False  ...  0.000000
# 23                      None     cycleway  1.65      True  ...  0.000000
# 24                      None     cycleway  1.80      True  ...  0.598189
# 25             Zeeburgerdijk     cycleway  2.10     False  ...  0.451301
# 26              Roomtuintjes     cycleway  None     False  ...  0.358362
# 27              Roomtuintjes     cycleway  None     False  ...  0.002145
# 28              Roomtuintjes     cycleway  None      True  ...  0.064568
# 29                      None     cycleway  None     False  ...  0.020303
#
#    sum_adjust        PET avg_exposure_percent avg_shade_percent    pop  \
# 0    7.210930  38.557958             0.414644          0.585356   31.0
# 1   12.824279  41.524704             0.632259          0.367741  660.0
# 2   11.136600  40.909272             0.524554          0.475446  629.0
# 3    9.541534  41.227089             0.466592          0.533408    NaN
# 4   20.693201  40.568399             0.997646          0.002354    NaN
# 5   20.772234  40.367615             0.999579          0.000421    NaN
# 6   11.040113  40.124224             0.624382          0.375618  694.0
# 7   10.410234  39.031511             0.609137          0.390863  694.0
# 8   10.514516  39.332733             0.602566          0.397434   27.0
# 9   10.262027  38.786652             0.601057          0.398943   27.0
# 10   9.019677  41.466043             0.601824          0.398176   13.0
# 11   5.391369  37.149407             0.304748          0.695252    NaN
# 12   4.906737  34.989448             0.297669          0.702331    NaN
# 13   2.114856  38.941594             0.116755          0.883245    NaN
# 14   5.831916  37.429586             0.374733          0.625267    NaN
# 15   4.669857  42.573119             0.234443          0.765557    NaN
# 16   9.039860  43.132057             0.443497          0.556503    NaN
# 17  11.316103  39.551629             0.675266          0.324734    NaN
# 18   4.098594  35.146099             0.244413          0.755587   40.0
# 19   4.729271  36.519389             0.285530          0.714470   27.0
# 20   7.028144  36.883792             0.401421          0.598579   13.0
# 21  11.926064  36.762901             0.689060          0.310940    NaN
# 22  12.581759  36.634528             0.735009          0.264991  212.0
# 23   9.892425  35.096642             0.553505          0.446495  212.0
# 24   7.556835  33.819617             0.366880          0.633120    8.0
# 25   6.947273  35.015410             0.297972          0.702028   46.0
# 26   3.383386  31.209950             0.138502          0.861498   38.0
# 27   5.185613  33.625546             0.328611          0.671389    NaN
# 28   4.291214  32.498833             0.277820          0.722180   38.0
# 29   5.964725  33.847673             0.407795          0.592205   20.0
#
#                                             buurtcode young_pop_pct  \
# 0                                {"BU0363AC03": 31.0}      3.225806
# 1   {"BU0363AC04": 71.0, "BU0363AC03": 269.0, "BU0...      5.303030
# 2   {"BU0363AC04": 71.0, "BU0363AC03": 238.0, "BU0...      5.405405
# 3                                                 NaN           NaN
# 4                                                 NaN           NaN
# 5                                                 NaN           NaN
# 6   {"BU0363AJ02": 379.0, "BU0363AJ04": 308.0, "BU...      9.365994
# 7   {"BU0363AJ02": 379.0, "BU0363AJ04": 308.0, "BU...      9.365994
# 8                                {"BU0363AK08": 27.0}      7.407407
# 9                                {"BU0363AK08": 27.0}      7.407407
# 10                               {"BU0363AF09": 13.0}      0.000000
# 11                                                NaN           NaN
# 12                                                NaN           NaN
# 13                                                NaN           NaN
# 14                                                NaN           NaN
# 15                                                NaN           NaN
# 16                                                NaN           NaN
# 17                                                NaN           NaN
# 18                               {"BU0363AK08": 40.0}      5.000000
# 19                               {"BU0363AK08": 27.0}      7.407407
# 20                               {"BU0363AK08": 13.0}      0.000000
# 21                                                NaN           NaN
# 22                              {"BU0363ME01": 212.0}      8.490566
# 23                              {"BU0363ME01": 212.0}      8.490566
# 24                                {"BU0363ME01": 8.0}      0.000000
# 25                               {"BU0363ME01": 46.0}     15.217391
# 26                               {"BU0363ME01": 38.0}     18.421053
# 27                                                NaN           NaN
# 28                               {"BU0363ME01": 38.0}     18.421053
# 29                               {"BU0363ME01": 20.0}     25.000000
#
#    old_pop_pct pop_unknown_pct
# 0     9.677419             0.0
# 1     9.696970             0.0
# 2     9.697933             0.0
# 3          NaN             NaN
# 4          NaN             NaN
# 5          NaN             NaN
# 6    13.400576             0.0
# 7    13.400576             0.0
# 8    29.629630             0.0
# 9    29.629630             0.0
# 10    0.000000             0.0
# 11         NaN             NaN
# 12         NaN             NaN
# 13         NaN             NaN
# 14         NaN             NaN
# 15         NaN             NaN
# 16         NaN             NaN
# 17         NaN             NaN
# 18   27.500000             0.0
# 19   29.629630             0.0
# 20   23.076923             0.0
# 21         NaN             NaN
# 22   15.566038             0.0
# 23   15.566038             0.0
# 24    0.000000             0.0
# 25   17.391304             0.0
# 26   21.052632             0.0
# 27         NaN             NaN
# 28   21.052632             0.0
# 29   20.000000             0.0
#
# [30 rows x 55 columns]

# %% [markdown]
# Set Geometry

# %%
#Set the geometry as it is defined by the first network pulled for the GeoDataFrame
gdf_heat_combined = gdf_heat_combined.set_geometry(gdf_heat_combined["geometry"], inplace=False)
gdf_heat_combined = gdf_heat_combined.fillna(0)

# %% [markdown]
# Generate threshold functions

# %%
#Fill in strings for column names
#Funtion which loops through various scores and sets the column value to 1 or 0 accordingly for threshold functionality
def shade_treshold(value):
    if value < 0.4:
        return 1
    else:
        return 0

def PET_treshold(value):
    if value >= 35:
        return 1
    else:
        return 0
    
def Business_bound(value):
    if value != 0:
        return 1
    else:
        return 0

def top_percent(value):
    if value > 0.96:
        return 1
    else:
        return 0

# %% [markdown]
# Do the math

# %%
#Function calculates our score based on the columns from the GeoDataFrame
def calculate_score(gdf_combined, column1_shade_sum, column2_PET, column3_mob, column1_shade_perc):
    max_shade = gdf_combined[column1_shade_sum].max()
    min_shade = gdf_combined[column1_shade_sum].min()
    max_PET = gdf_combined[column2_PET].max()
    min_PET = gdf_combined[column2_PET].min()


    #Set column to 0 or 1 based on threshold values above
    gdf_combined['shade_tresh'] = gdf_combined[column1_shade_perc].apply(shade_treshold)
    gdf_combined['PET_tresh'] = gdf_combined[column2_PET].apply(PET_treshold)

    #Reprojected Shade and PET score from 0-1 to make them comparable
    gdf_combined['shade_score'] = ((gdf_combined[column1_shade_sum]-min_shade)/(max_shade-min_shade)) 
    gdf_combined['PET_score'] = ((gdf_combined[column2_PET]-min_PET)/(max_PET-min_PET))

    #Calculate final risk score per street
    gdf_combined['Final_score_all'] = gdf_combined['shade_tresh']*gdf_combined['PET_tresh']*(((gdf_combined['shade_score']) + (gdf_combined['PET_score']))/2) #Add weights to criteria if wanted
    
    #Calulate top 4% percent of streets in Amsterdam based on modelled intensity, requirement that Final_score_all is not 0
    gdf_combined['busy_select'] = (gdf_combined['Final_score_all'].apply(Business_bound))
    gdf_combined['busy_after_crit'] = gdf_combined[column3_mob]*gdf_combined['busy_select']
    gdf_combined['busy_after_crit'] = gdf_combined['busy_after_crit'].rank(pct = True)
    gdf_combined['busy_treshold'] =  gdf_combined['busy_after_crit'].apply(top_percent)
    gdf_combined['Final_score_4_perc'] = gdf_combined['Final_score_all']*gdf_combined['busy_treshold']

    #Add column defining with category when displaying the flow values later
    gdf_jenks = gdf_combined.loc[gdf_combined[column3_mob] != 0]
    jnb = jenkspy.JenksNaturalBreaks(3)
    jnb.fit(gdf_jenks[column3_mob])
    brea = jnb.breaks_
    breaki = [0] + brea
    gdf_combined['jenkins_bin'] = pd.cut(gdf_combined[column3_mob], bins=breaki, labels=['bin_1', 'bin_2', 'bin_3', 'bin_4'], include_lowest = True) 
    
    return gdf_combined

# %%
#Implementing the previous function
gdf_heat_combined = calculate_score(gdf_heat_combined, 'sum_adjust', 'PET', 'pop', 'avg_shade_percent')
gdf_heat_combined = gdf_heat_combined.round(decimals=3)

print(gdf_heat_combined.head(30))
# Out:
#                      edge_x         u            v  key      osmid  oneway  \
# 0       (6316199, 46388769)   6316199     46388769    0    7372614   False
# 1      (6316199, 451946447)   6316199    451946447    0    7372610   False
# 2     (6316199, 1360288038)   6316199   1360288038    0    4745774   False
# 3     (6316199, 5825714203)   6316199   5825714203    0  562720340   False
# 4    (16568167, 3175727845)  16568167   3175727845    0  311836384   False
# 5   (16568167, 10633464529)  16568167  10633464529    0  311836398   False
# 6      (25596455, 46356773)  25596455     46356773    0   37481780   False
# 7    (25596455, 8383889398)  25596455   8383889398    0   37481780   False
# 8    (25596455, 8383889399)  25596455   8383889399    0   37481778   False
# 9    (25596455, 8383889401)  25596455   8383889401    0   37481778   False
# 10   (25596477, 2739513281)  25596477   2739513281    0   23289375   False
# 11   (25596477, 2739513283)  25596477   2739513283    0  113952975   False
# 12   (25596477, 9033130238)  25596477   9033130238    0   23289374   False
# 13     (25645986, 25645987)  25645986     25645987    0   37481778   False
# 14     (25645986, 46352556)  25645986     46352556    0   37481778   False
# 15   (25645987, 4854477788)  25645987   4854477788    0   37481778   False
# 16   (25645988, 4854477788)  25645988   4854477788    0   37481778   False
# 17   (25645988, 8383889402)  25645988   8383889402    0   37481778   False
# 18     (25645989, 46359454)  25645989     46359454    0   37481777   False
# 19    (25645989, 438278570)  25645989    438278570    0   37481778   False
# 20   (25645989, 8383889374)  25645989   8383889374    0   37481778   False
# 21     (25645990, 46361924)  25645990     46361924    0    7046058   False
# 22    (25645990, 452982483)  25645990    452982483    0   33514339   False
# 23  (25645990, 10012107912)  25645990  10012107912    0  115708738   False
# 24   (25658577, 3307094070)  25658577   3307094070    0  504684738   False
# 25   (25658577, 4589025084)  25658577   4589025084    0  115743517   False
# 26   (25658577, 9831335847)  25658577   9831335847    0    4270806   False
# 27     (25658578, 25658580)  25658578     25658580    0    4270806   False
# 28   (25658578, 1367854685)  25658578   1367854685    0    4270806   False
# 29   (25658578, 9831335842)  25658578   9831335842    0  323937630   False
#
#                         name      highway width  reversed  ...  shade_tresh  \
# 0                     Singel  residential     0     False  ...            0
# 1                          0  residential     0     False  ...            1
# 2                  Raamsteeg     cycleway  1.80      True  ...            0
# 3                     Singel  residential     0      True  ...            0
# 4                          0      footway     0     False  ...            1
# 5                          0      footway     0     False  ...            1
# 6   Wilhelmina Blombergplein   pedestrian     0      True  ...            1
# 7   Wilhelmina Blombergplein   pedestrian     0     False  ...            1
# 8              Alexanderkade      footway     0      True  ...            1
# 9              Alexanderkade      footway     0     False  ...            1
# 10        Nieuwe Herengracht  residential     0     False  ...            1
# 11  Jonas Daniël Meijerplein   pedestrian     0      True  ...            0
# 12  Jonas Daniël Meijerplein   pedestrian     0      True  ...            0
# 13             Alexanderkade      footway     0      True  ...            0
# 14             Alexanderkade      footway     0     False  ...            0
# 15             Alexanderkade      footway     0      True  ...            0
# 16             Alexanderkade      footway     0     False  ...            0
# 17             Alexanderkade      footway     0      True  ...            1
# 18                         0      footway     0      True  ...            0
# 19             Alexanderkade      footway     0     False  ...            0
# 20             Alexanderkade      footway     0      True  ...            0
# 21                         0     cycleway  1.80     False  ...            1
# 22                         0     cycleway  1.65     False  ...            1
# 23                         0     cycleway  1.65      True  ...            0
# 24                         0     cycleway  1.80      True  ...            0
# 25             Zeeburgerdijk     cycleway  2.10     False  ...            0
# 26              Roomtuintjes     cycleway     0     False  ...            0
# 27              Roomtuintjes     cycleway     0     False  ...            0
# 28              Roomtuintjes     cycleway     0      True  ...            0
# 29                         0     cycleway     0     False  ...            0
#
#    PET_tresh shade_score PET_score Final_score_all busy_select  \
# 0          1       0.346     0.851           0.000           0
# 1          1       0.616     0.916           0.766           1
# 2          1       0.535     0.903           0.000           0
# 3          1       0.458     0.910           0.000           0
# 4          1       0.993     0.895           0.944           1
# 5          1       0.997     0.891           0.944           1
# 6          1       0.530     0.885           0.708           1
# 7          1       0.500     0.861           0.681           1
# 8          1       0.505     0.868           0.686           1
# 9          1       0.493     0.856           0.674           1
# 10         1       0.433     0.915           0.674           1
# 11         1       0.259     0.820           0.000           0
# 12         0       0.236     0.772           0.000           0
# 13         1       0.102     0.859           0.000           0
# 14         1       0.280     0.826           0.000           0
# 15         1       0.224     0.940           0.000           0
# 16         1       0.434     0.952           0.000           0
# 17         1       0.543     0.873           0.708           1
# 18         1       0.197     0.776           0.000           0
# 19         1       0.227     0.806           0.000           0
# 20         1       0.337     0.814           0.000           0
# 21         1       0.573     0.811           0.692           1
# 22         1       0.604     0.808           0.706           1
# 23         1       0.475     0.775           0.000           0
# 24         0       0.363     0.746           0.000           0
# 25         1       0.334     0.773           0.000           0
# 26         0       0.162     0.689           0.000           0
# 27         0       0.249     0.742           0.000           0
# 28         0       0.206     0.717           0.000           0
# 29         0       0.286     0.747           0.000           0
#
#    busy_after_crit busy_treshold Final_score_4_perc jenkins_bin
# 0            0.437             0              0.000       bin_2
# 1            0.988             1              0.766       bin_2
# 2            0.437             0              0.000       bin_2
# 3            0.437             0              0.000       bin_1
# 4            0.437             0              0.000       bin_1
# 5            0.437             0              0.000       bin_1
# 6            0.988             1              0.708       bin_2
# 7            0.988             1              0.681       bin_2
# 8            0.917             0              0.000       bin_2
# 9            0.917             0              0.000       bin_2
# 10           0.900             0              0.000       bin_2
# 11           0.437             0              0.000       bin_1
# 12           0.437             0              0.000       bin_1
# 13           0.437             0              0.000       bin_1
# 14           0.437             0              0.000       bin_1
# 15           0.437             0              0.000       bin_1
# 16           0.437             0              0.000       bin_1
# 17           0.437             0              0.000       bin_1
# 18           0.437             0              0.000       bin_2
# 19           0.437             0              0.000       bin_2
# 20           0.437             0              0.000       bin_2
# 21           0.437             0              0.000       bin_1
# 22           0.968             1              0.706       bin_2
# 23           0.437             0              0.000       bin_2
# 24           0.437             0              0.000       bin_2
# 25           0.437             0              0.000       bin_2
# 26           0.437             0              0.000       bin_2
# 27           0.437             0              0.000       bin_1
# 28           0.437             0              0.000       bin_2
# 29           0.437             0              0.000       bin_2
#
# [30 rows x 65 columns]

# %% [markdown]
# Export as GEOJson

# %%
#Export file as GEOJson
with open('./root/Outputs/4_Final_Heat_Risk_Score.geojson' , 'w') as file:
    file.write(gdf_heat_combined.to_json())
